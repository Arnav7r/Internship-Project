# %%
import sys
print(sys.version)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
# !python -m venv tfenv

# %%
import sys
print(sys.version)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
import platform
print(platform.python_version())
# Out:
# 3.12.10

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    "D:\Python Codes\Tomato-Datasets",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    "D:\Python Codes\Tomato-Datasets",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 4392 images belonging to 3 classes.
# Found 4392 images belonging to 3 classes.
# <>:11: SyntaxWarning: invalid escape sequence '\P'
# <>:18: SyntaxWarning: invalid escape sequence '\P'
# <>:11: SyntaxWarning: invalid escape sequence '\P'
# <>:18: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\prana\AppData\Local\Temp\ipykernel_26436\3324600155.py:11: SyntaxWarning: invalid escape sequence '\P'
#   "D:\Python Codes\Tomato-Datasets",
# C:\Users\prana\AppData\Local\Temp\ipykernel_26436\3324600155.py:18: SyntaxWarning: invalid escape sequence '\P'
#   "D:\Python Codes\Tomato-Datasets",

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 0

# %%
history = model.fit(
    train_data,
  validation_data=test_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.8932 - loss: 0.2726 - val_accuracy: 0.9633 - val_loss: 0.1226
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.9444 - loss: 0.1379 - val_accuracy: 0.9718 - val_loss: 0.0817
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9572 - loss: 0.1086 - val_accuracy: 0.9761 - val_loss: 0.0749
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9674 - loss: 0.0921 - val_accuracy: 0.9765 - val_loss: 0.0714
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9713 - loss: 0.0756 - val_accuracy: 0.9768 - val_loss: 0.0654
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 218s 2s/step - accuracy: 0.9724 - loss: 0.0763 - val_accuracy: 0.9834 - val_loss: 0.0503
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.9777 - loss: 0.0672 - val_accuracy: 0.9813 - val_loss: 0.0509
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9699 - loss: 0.0763 - val_accuracy: 0.9804 - val_loss: 0.0551
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.9804 - loss: 0.0547 - val_accuracy: 0.9857 - val_loss: 0.0420
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.9750 - loss: 0.0634 - val_accuracy: 0.9772 - val_loss: 0.0554

# %%
loss, accuracy = model.evaluate(test_data)

print("Accuracy:", accuracy)
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 93s 672ms/step - accuracy: 0.9772 - loss: 0.0554
# Accuracy: 0.9772313237190247

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(
    "D:\\Python Codes\\Tomato-Datasets\\Tomato___healthy\\0cfee8b1-5de4-4118-9e25-f9c37bb6f17e___GH_HL Leaf 252.JPG",
    target_size=(224,224)
)

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [[1.20141674e-04 1.49322364e-06 9.99878287e-01]]
