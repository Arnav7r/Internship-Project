# %%
import sys
print(sys.version)
# Out:
# 3.14.4 (tags/v3.14.4:23116f9, Apr  7 2026, 14:10:54) [MSC v.1944 64 bit (AMD64)]

# %%
# !python -m venv tfenv

# %%
# !python -m venv tfenv

# %%
import sys
print(sys.version)
# Out:
# 3.14.4 (tags/v3.14.4:23116f9, Apr  7 2026, 14:10:54) [MSC v.1944 64 bit (AMD64)]
