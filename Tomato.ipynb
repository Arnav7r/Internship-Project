# %% [markdown]
# Arnav

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import platform
print(platform.python_version())
# Out:
# 3.13.1

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    r"C:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\Tomato-Datasets",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    r"C:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\Tomato-Datasets",
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 4392 images belonging to 3 classes.
# Found 4392 images belonging to 3 classes.

# %%
class_names = list(train_data.class_indices.keys())

images, labels = next(train_data)

plt.figure(figsize=(10,10))

for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(images[i])
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")

plt.show()

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    # 224 = height, 224 = weight, 3 = rgb
    input_shape=(224,224,3)
)

base_model.trainable = False

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)

from PIL import Image
print(Image.__version__)
# Out:
# c:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\.venv\Scripts\python.exe
# 12.2.0

# %%
import sys
print(sys.executable)

from PIL import Image
print("Pillow version:", Image.__version__)
# Out:
# c:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\.venv\Scripts\python.exe
# Pillow version: 12.2.0

# %%
import sys
print(sys.version)
# Out:
# 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]

# %%
pip install --upgrade tensorflow keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.utils import load_img
from PIL import Image

print(Image.__version__)
# Out:
# 12.2.0

# %%
from PIL import Image
print("PIL OK")

from tensorflow.keras.utils import load_img
print("load_img imported OK")
# Out:
# PIL OK
# load_img imported OK

# %%
import PIL
from PIL import Image

print("PIL module:", PIL.__file__)
print("Image module:", Image.__file__)
# Out:
# PIL module: c:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\.venv\Lib\site-packages\PIL\__init__.py
# Image module: c:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\.venv\Lib\site-packages\PIL\Image.py

# %%
from keras.src.utils import image_utils

print(image_utils.pil_image)
# Out:
# <module 'PIL.Image' from 'c:\\Users\\raiar\\OneDrive\\Documents\\GitHub\\Internship-Project\\.venv\\Lib\\site-packages\\PIL\\Image.py'>

# %%
import sys
# !{sys.executable} -m pip uninstall -y pillow
# !{sys.executable} -m pip install pillow
# Out:
# Found existing installation: pillow 12.2.0
# Uninstalling pillow-12.2.0:
#   Successfully uninstalled pillow-12.2.0
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\.venv\Lib\site-packages\~.l'.
# You can safely remove it manually.
# ...
#   Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from keras.src.utils import image_utils
print(image_utils.pil_image)
# Out:
# <module 'PIL.Image' from 'c:\\Users\\raiar\\OneDrive\\Documents\\GitHub\\Internship-Project\\.venv\\Lib\\site-packages\\PIL\\Image.py'>

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
history = model.fit(
    train_data,
    
    validation_data=test_data,
    epochs=10
)
# Out:
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.8791 - loss: 0.2911 - val_accuracy: 0.9501 - val_loss: 0.1318
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 118s 856ms/step - accuracy: 0.9483 - loss: 0.1396 - val_accuracy: 0.9567 - val_loss: 0.1199
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 932ms/step - accuracy: 0.9556 - loss: 0.1137 - val_accuracy: 0.9577 - val_loss: 0.1106
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 137s 992ms/step - accuracy: 0.9686 - loss: 0.0903 - val_accuracy: 0.9661 - val_loss: 0.0932
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 129s 937ms/step - accuracy: 0.9699 - loss: 0.0892 - val_accuracy: 0.9847 - val_loss: 0.0542
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 131s 947ms/step - accuracy: 0.9695 - loss: 0.0768 - val_accuracy: 0.9872 - val_loss: 0.0425
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 124s 899ms/step - accuracy: 0.9738 - loss: 0.0689 - val_accuracy: 0.9850 - val_loss: 0.0420
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(test_data)

print("Accuracy:", accuracy)
# Out:
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 44s 321ms/step - accuracy: 0.9904 - loss: 0.0282
# Accuracy: 0.9904371500015259

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(
    r"C:\Users\raiar\OneDrive\Documents\GitHub\Internship-Project\Tomato-Datasets\Tomato___healthy\0aacdad5-c9b9-4309-96e3-0797bbed1375___RS_HL 9836.JPG",
    target_size=(224,224)
)

img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0

prediction = model.predict(img_array)

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [[5.8428463e-07 7.9484043e-06 9.9999142e-01]]

# %%
print(accuracy)
# Out:
# 0.9904371500015259

# %%
history.history['loss'][:5]
# Out:
# [0.2911219596862793,
#  0.13964012265205383,
#  0.11374232918024063,
#  0.09033177047967911,
#  0.0892224833369255]

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model.save("leaf_model.keras")
